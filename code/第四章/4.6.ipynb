# %% [markdown]
# ## Graph RAG应用实战
#
# ### Graph RAG以及与传统RAG的优劣
#
# Graph RAG 是将知识图谱（Knowledge Graph）引入检索增强生成（RAG）框架的一种扩展形式。它利用结构化的知识显式表示实体及其关系，从而显著提升系统的推理能力和回答准确性。相比于传统 RAG 仅基于向量检索的机制，Graph RAG 在复杂任务中具有独特的优势。
#
#  **优点：深度理解** ：通过显式的实体和关系表达，Graph RAG 能够支持复杂的问答和逻辑推理。 **高准确性** ：由于知识图谱中知识的结构化表示，减少了生成模型出现幻觉现象（hallucination）的可能性。
#
#  **缺点：构建复杂** ：知识图谱的构建和维护需要大量时间和资源投入。 **灵活性有限** ：对于实时更新和动态信息支持较差，难以应对快速变化的场景。
#
# ### 图数据库介绍
#
# 图数据库是 Graph RAG 的核心组件，用于存储和管理知识图谱。它能够高效处理复杂的关系查询，同时提供灵活的结构和强大的查询能力。
#
#  **特点：高效的关系查询** ：图数据库优化了实体与实体之间关系的查找和操作，性能优于传统关系型数据库。 **灵活的结构** ：支持动态添加节点（实体）和边（关系），能够应对多样化的数据变化。 **强大的查询语言** ：如 Neo4j 的 Cypher，方便用户编写复杂查询逻辑。
#
#  **常用图数据库：**
#
# - **Neo4j** ：功能强大，易于使用的企业级图数据库。
#
# - **JanusGraph** ：分布式的开源图数据库，适合大规模图数据管理。
#
# ### 构建三元组并上传图数据库
#
# 知识图谱的核心是三元组（Triplets），由节点、关系、属性组成：
#
#  **节点（Node/Entity）** ：表示实体，是图中的顶点
#
#  **关系（Relationship/Edge）** ：表示实体之间的联系，是图中的边
#
#  **属性（Property/Attribute）** ：节点或关系的特征描述
#
# 例如我们的有一段文本：

# %%
text_example = """
CAMEL和DATAWHALE是两个活跃的AI开源社区。
CAMEL致力于推动人工智能技术的发展，帮助开发者更好地进行AI研究和应用。
DateWhale通过开源项目和社区活动，促进知识分享和技术交流。这两个社区都为AI领域的创新和进步做出了重要贡献。"""

# %% [markdown]
# 我们可以从中找出CAMEL、DataWhale等等这些节点，那么CAMEL和人工智能技术的发展之间的关系可以表述为：`CAMEL` `"致力于"` `人工智能技术的发展`。而CAMEL的属性可以为`"AI开源社区"`。
#
# 1. **信息抽取**
#
# 之前我们可能通过一些NLP技术来做信息的抽取，现在我们可以直接使用LLM来完成这件事情。例如我们通过一些简单的prompt工程来完成这个目的：

# %%
from camel.models import ModelFactory
from camel.types import ModelPlatformType
from camel.loaders import UnstructuredIO
from camel.agents import ChatAgent

from dotenv import load_dotenv
import os   

load_dotenv()

api_key = os.getenv("MODELSCOPE_API_KEY")

model = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI_COMPATIBLE_MODEL,
    model_type="Qwen/Qwen2.5-72B-Instruct",
    url='https://api-inference.modelscope.cn/v1/',
    api_key=api_key
)

sys_msg =  """
            你是一个图数据库专家，你的任务是从给定的内容中提取实体和关系，构建知识图谱。
            
            知识图谱的基本组成：
            1. 节点（Node）：表示实体，包含id和type属性
            2. 关系（Relationship）：表示实体之间的联系
            3. 属性（Property）：节点或关系的附加信息

            示例输入：
            "小明，2008年9月13日出生，男。五行属水，性格开朗。"

            期望输出：
            Nodes:
            Node(id="小明", type="人")
            Node(id="水", type="五行")
            Node(id="开朗", type="性格")
            Node(id="2008年9月13日", type="时间")

            Relationships:
            Relationship(subj=Node(id="小明", type="人"), obj=Node(id="水", type="五行"), type="五行属性")
            Relationship(subj=Node(id="小明", type="人"), obj=Node(id="开朗", type="性格"), type="性格特征")
            Relationship(subj=Node(id="小明", type="人"), obj=Node(id="2008年9月13日", type="时间"), type="出生日期")

            请从以下内容中提取实体和关系：
            """
graphprocessor = ChatAgent(
    system_message=sys_msg,
    model=model,
    )

text_example = """
CAMEL和DATAWHALE是两个活跃的AI开源社区。
CAMEL致力于推动人工智能技术的发展，帮助开发者更好地进行AI研究和应用。
DateWhale通过开源项目和社区活动，促进知识分享和技术交流。这两个社区都为AI领域的创新和进步做出了重要贡献。"""

# %% [markdown]
# 我们首先通过一个prompt来定义来agent的功能，以及设置好我们案例文本。

# %%
response = graphprocessor.step(input_message= text_example)
print (response.msgs[0].content)
# Out:
# Nodes:
# Node(id="CAMEL", type="社区")
# Node(id="DATAWHALE", type="社区")
# Node(id="AI", type="领域")
# Node(id="AI研究和应用", type="目标")
# Node(id="知识分享", type="活动")
# Node(id="技术交流", type="活动")
# Node(id="创新和进步", type="贡献")
#
# Relationships:
# Relationship(subj=Node(id="CAMEL", type="社区"), obj=Node(id="AI", type="领域"), type="关注领域")
# Relationship(subj=Node(id="CAMEL", type="社区"), obj=Node(id="AI研究和应用", type="目标"), type="促进目标")
# Relationship(subj=Node(id="DATAWHALE", type="社区"), obj=Node(id="AI", type="领域"), type="关注领域")
# Relationship(subj=Node(id="DATAWHALE", type="社区"), obj=Node(id="知识分享", type="活动"), type="举办活动")
# Relationship(subj=Node(id="DATAWHALE", type="社区"), obj=Node(id="技术交流", type="活动"), type="举办活动")
# Relationship(subj=Node(id="CAMEL", type="社区"), obj=Node(id="创新和进步", type="贡献"), type="做出贡献")
# Relationship(subj=Node(id="DATAWHALE", type="社区"), obj=Node(id="创新和进步", type="贡献"), type="做出贡献")

# %% [markdown]
# 可以看到，对于信息抽取这个任务，LLM能完成的相当出色。当然如果不想自己写prompt的话，CAMEL也有预设好的`KnowledgeGraphAgent`供我们一键调用，更改这里的参数  `parse_graph_elements`  可以设定Agent返回的信息格式，False返回的是一个字符串，设置为True则返回一个自定义的`GraphElement`类：

# %%
from camel.agents import KnowledgeGraphAgent

uio = UnstructuredIO()
kg_agent = KnowledgeGraphAgent(model=model)

# 从给定文本创建一个元素
element_example = uio.create_element_from_text(
    text=text_example, element_id="0"
)

# 让知识图谱Agent提取节点和关系信息
ans_element = kg_agent.run(element_example, parse_graph_elements=False)
print(ans_element)
# Out:
# Nodes:
#
# Node(id='CAMEL', type='Community')
# Node(id='DATAWHALE', type='Community')
# Node(id='AI Research and Application', type='Field')
# Node(id='Knowledge Sharing and Technical Exchange', type='Activity')
#
# Relationships:
#
# Relationship(subj=Node(id='CAMEL', type='Community'), obj=Node(id='AI Research and Application', type='Field'), type='Promotes')
# Relationship(subj=Node(id='DATAWHALE', type='Community'), obj=Node(id='Knowledge Sharing and Technical Exchange', type='Activity'), type='Facilitates')
# Relationship(subj=Node(id='CAMEL', type='Community'), obj=Node(id='DATAWHALE', type='Community'), type='ContributesTo')

# %% [markdown]
# 2. **上传数据库**
#
# 现在我们有了节点和关系信息，下一步就该把他们上传到数据库里了。
#
# 首先我们要初始化我们的图数据库，这里我们可以使用[Neo4j(点击跳转)](https://neo4j.com/):

# %%
from camel.storages import Neo4jGraph

n4j = Neo4jGraph(
    url="你的url",
    username="neo4j",
    password="你的password",
)

# %% [markdown]
# CAMEL已经将上传到图数据这一个操作为我们一键集成，我们只需要使用一个简单的命令调用即可(需要搭配`KnowledgeGraphAgent一起使用，设定parse_graph_elements=True`)：

# %%
# 检查实体信息
graph_elements = kg_agent.run(element_example, parse_graph_elements=True)
print(graph_elements)

# %% [markdown]
# 将提取的图信息添加到 Neo4j 数据库中：

# %%
n4j.add_graph_elements(graph_elements=[graph_elements])

# %% [markdown]
# <img src="img/image8.png" alt="image" width="800">
#
# 我们再回到neo4j就可以看到我们构建的知识图谱啦！

# %% [markdown]
# ### 实践案例
#
# 在这个案例中，我们将展示如何以混合方式运行 RAG，结合向量检索和知识图谱检索，以查询和探索存储的知识。
#
# 首先我们使用本地部署的e5-large-v2作为我们的embedding模型(如果本地没有的话会自动下载)。

# %%
from camel.models import ModelFactory
from camel.types import ModelPlatformType, ModelType
from camel.loaders import UnstructuredIO
from camel.storages import Neo4jGraph
from camel.retrievers import AutoRetriever
from camel.types import StorageType
from camel.agents import ChatAgent, KnowledgeGraphAgent
from camel.messages import BaseMessage
from camel.embeddings import SentenceTransformerEncoder

from dotenv import load_dotenv
import os   

load_dotenv()
api_key = os.getenv("MODELSCOPE_API_KEY")

# 设置检索器
camel_retriever = AutoRetriever(
    vector_storage_local_path="local_data/embedding_storage",
    storage_type=StorageType.QDRANT,
    embedding_model=SentenceTransformerEncoder(model_name='intfloat/e5-large-v2'),
)

model = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI_COMPATIBLE_MODEL,
    model_type="Qwen/Qwen2.5-72B-Instruct",
    url='https://api-inference.modelscope.cn/v1/',
    api_key=api_key
)

# n4j = Neo4jGraph(
#     url="你的url",
#     username="你的username",
#     password="你的密码",
# )

uio = UnstructuredIO()
kg_agent = KnowledgeGraphAgent(model=model)

# %% [markdown]
# 之后我们设置好我们想了解的内容，这里我们首先让它根据向量检索的方式来检索相关信息：

# %%
# 设置query
query="DataWhale和CAMEL之间是什么关系。"

# 使用向量检索器获取相关内容
vector_result = camel_retriever.run_vector_retriever(
    query=query,
    contents="""在一个神奇的动物王国里，住着一只聪明的骆驼，名叫CAMEL，以及一只智慧的鲸鱼，名叫DataWhale。CAMEL生活在辽阔的沙漠中，而DataWhale则畅游在无边无际的海洋里。虽然它们的栖息地截然不同，但它们都对探索新知充满了浓厚的兴趣。

有一天，CAMEL在沙漠中偶然发现了一块古老的石板，上面刻满了奇怪的符号和图案。CAMEL意识到这可能是一份通往巨大宝藏的地图，但它无法解读这些符号。于是，它决定去寻找帮助。

与此同时，DataWhale在海洋深处发现了一卷古老的羊皮纸，上面也布满了类似的符号。这让DataWhale感到非常好奇，因为它知道这些符号可能蕴藏着某种秘密，但它同样无法破译。

通过一只飞翔在天空中的信使鸟，CAMEL和DataWhale得知彼此的发现，并决定合作解开这个谜团。骆驼踏上了漫长的旅程，穿越沙漠来到了海洋边缘，而鲸鱼则游到岸边，与CAMEL会合。

在一起研究这些古老的符号时，CAMEL运用了它在沙漠中磨炼出的耐心和智慧，而DataWhale则利用它在海洋中获得的知识和洞察力。经过一番努力，它们终于解读出这些符号的含义。原来，这些符号描绘的是一个连接沙漠和海洋的秘密通道，通道的尽头藏着一座知识的宝库。

满怀着激动与期待，CAMEL和DataWhale沿着地图所指引的方向，一同踏上了寻找宝库的旅程。一路上，它们克服了重重困难，彼此扶持与信任，终于找到了那座传说中的宝库。里面并不是金银财宝，而是无数的古老书籍和知识卷轴。

通过这次冒险，CAMEL和DataWhale不仅获得了丰富的知识，还建立了深厚的友谊。它们将这些知识带回了各自的家园，与其他动物分享，从而推动了整个动物王国的进步与发展。

这个故事告诉我们，不同背景和能力的个体，通过合作与分享，能够创造出超越想象的成果，开拓出更为广阔的未来。CAMEL和DataWhale的友谊也成为了动物王国中流传不息的传奇。""",
)

# 打印向量检索的结果
print(vector_result)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# {'Original Query': 'DataWhale和CAMEL之间是什么关系。', 'Retrieved Context': ['在一个神奇的动物王国里，住着一只聪明的骆驼，名叫CAMEL，以及一只智慧的鲸鱼，名叫DataWhale。CAMEL生活在辽阔的沙漠中，而DataWhale则畅游在无边无际的海洋里。虽然它们的栖息地截然不同，但它们都对探索新知充满了浓厚的兴趣。 有一天，CAMEL在沙漠中偶然发现了一块古老的石板，上面刻满了奇怪的符号和图案。CAMEL意识到这可能是一份通往巨大宝藏的地图，但它无法解读这些符号。于是，它决定去寻找帮助。 与此同时，DataWhale在海洋深处发现了一卷古老的羊皮纸，上面也布满了类似的符号。这让DataWhale感到非常好奇，因为它知道这些符号可能蕴藏着某种秘密，但它同样无法破译。 通过一只飞翔在天空中的信使鸟，CAMEL和DataWhale得知彼此的发现，并决定合作解开这个谜团。骆驼踏上了漫长的旅程，穿越沙漠来到了海洋边缘，而鲸鱼则游到岸边，与CAMEL会合。']}

# %% [markdown]
# 接下来，我们可以创建我们的知识图谱：

# %%
# 从CRAB网站解析内容，并使用知识图谱Agent创建知识图谱数据，将信息存储到图数据库中。

elements = uio.create_element_from_text(
    text="""在一个神奇的动物王国里，住着一只聪明的骆驼，名叫CAMEL，以及一只智慧的鲸鱼，名叫DataWhale。CAMEL生活在辽阔的沙漠中，而DataWhale则畅游在无边无际的海洋里。虽然它们的栖息地截然不同，但它们都对探索新知充满了浓厚的兴趣。

有一天，CAMEL在沙漠中偶然发现了一块古老的石板，上面刻满了奇怪的符号和图案。CAMEL意识到这可能是一份通往巨大宝藏的地图，但它无法解读这些符号。于是，它决定去寻找帮助。

与此同时，DataWhale在海洋深处发现了一卷古老的羊皮纸，上面也布满了类似的符号。这让DataWhale感到非常好奇，因为它知道这些符号可能蕴藏着某种秘密，但它同样无法破译。

通过一只飞翔在天空中的信使鸟，CAMEL和DataWhale得知彼此的发现，并决定合作解开这个谜团。骆驼踏上了漫长的旅程，穿越沙漠来到了海洋边缘，而鲸鱼则游到岸边，与CAMEL会合。

在一起研究这些古老的符号时，CAMEL运用了它在沙漠中磨炼出的耐心和智慧，而DataWhale则利用它在海洋中获得的知识和洞察力。经过一番努力，它们终于解读出这些符号的含义。原来，这些符号描绘的是一个连接沙漠和海洋的秘密通道，通道的尽头藏着一座知识的宝库。

满怀着激动与期待，CAMEL和DataWhale沿着地图所指引的方向，一同踏上了寻找宝库的旅程。一路上，它们克服了重重困难，彼此扶持与信任，终于找到了那座传说中的宝库。里面并不是金银财宝，而是无数的古老书籍和知识卷轴。

通过这次冒险，CAMEL和DataWhale不仅获得了丰富的知识，还建立了深厚的友谊。它们将这些知识带回了各自的家园，与其他动物分享，从而推动了整个动物王国的进步与发展。

这个故事告诉我们，不同背景和能力的个体，通过合作与分享，能够创造出超越想象的成果，开拓出更为广阔的未来。CAMEL和DataWhale的友谊也成为了动物王国中流传不息的传奇。"""
)

graph_element = kg_agent.run(elements, parse_graph_elements=True)
n4j.add_graph_elements(graph_elements=[graph_element])

# %% [markdown]
# 下面这个漂亮的图谱就是我们创建的结果啦！
# <img src="img/image9.png" alt="image" width="800">

# %%
# 根据query创建一个元素
query_element = uio.create_element_from_text(
    text=query, element_id="1"
)

# 让知识图谱agent从查询中提取节点和关系信息
ans_element = kg_agent.run(query_element, parse_graph_elements=True)

# %% [markdown]
# 有细心的小伙伴应该发现了，我们在text中并没有给DataWhale或者CAMEL有`Organization`的描述，但是最后的结果却含有，这是因为在使用KnowledgeGraphAgent的run函数时会将检索的到的结果再经过一遍大模型的润色，我们如果想查询原始的数据可以使用neo4j的查询语句：
#
#  **匹配知识图谱存储中的实体：**

# %%
# 匹配从query中获得的实体在知识图谱存储内容中的信息
kg_result = []
for node in ans_element.nodes:
    n4j_query = f"""
MATCH (n {{id: '{node.id}'}})-[r]->(m)
RETURN 'Node ' + n.id + ' (label: ' + labels(n)[0] + ') has relationship ' + type(r) + ' with Node ' + m.id + ' (label: ' + labels(m)[0] + ')' AS Description
UNION
MATCH (n)<-[r]-(m {{id: '{node.id}'}})
RETURN 'Node ' + m.id + ' (label: ' + labels(m)[0] + ') has relationship ' + type(r) + ' with Node ' + n.id + ' (label: ' + labels(n)[0] + ')' AS Description
"""
    result = n4j.query(query=n4j_query)
    kg_result.extend(result)

kg_result = [item['Description'] for item in kg_result]

# 显示来自知识图谱数据库的结果
print(kg_result)

# %% [markdown]
# 这样就可以检索出我们query对应的这些信息啦。

# %%
# 合并来自向量搜索和知识图谱实体搜索的结果
comined_results = str(vector_result) + "\n".join(kg_result)

print(comined_results)

# %%
# 设置代理
sys_msg = BaseMessage.make_assistant_message(
    role_name="CAMEL Agent",
    content="""您是一个有用的助手来回答问题，
        我将给您原始查询和检索到的上下文，
    根据检索到的上下文回答原始查询。""",
)

camel_agent = ChatAgent(system_message=sys_msg,
                        model=model)

# 将检索到的信息传递给智能体
user_prompt=f"""
原始查询是 {query}
检索到的上下文是 {comined_results}
"""

user_msg = BaseMessage.make_user_message(
    role_name="CAMEL User", content=user_prompt
)

# 获取响应
agent_response = camel_agent.step(user_msg)

print(agent_response.msg.content)

# %% [markdown]
# 至此恭喜你学会了如何使用基础的向量检索和基于图数据库的检索！下面让我们看看，Graph还有哪些可以用的地方吧。
#
# ### 进阶案例
#
# 接下来的案例会演示如何利用设置和利用CAMEL的检索增强生成 （RAG） 与 Firecrawl 相结合，以实现高效的 Web 抓取、多代理角色扮演任务和知识图谱构建。我们将使用LLM 对 2024 年巴黎奥运会上的土耳其射击运动员进行全面研究。
#
# 在本笔记本中，您将探索：
#
# - **CAMEL：** 一个强大的多代理框架，支持 Retrieval-Augmented Generation 和多代理角色扮演场景，允许执行复杂的 AI 驱动任务。
#
# - **Firecrawl** ：一个强大的网络抓取工具，可简化从各种网页中提取和清理内容的过程。
#
# - **AgentOps** ：跟踪和分析 CAMEL Agent 的运行情况。
#
# - **Qdrant** ：一种高效的向量存储系统，与 Camel 的 AutoRetriever 一起使用，根据向量相似性存储和检索相关信息。
#
# - **Neo4j** ：领先的图数据库管理系统，用于构建和存储知识图谱，使实体之间的复杂关系能够高效映射和查询。
#
# - **DuckDuckGo 搜索** ： 在 SearchToolkit 中用于从 Web 收集相关 URL 和信息，作为检索初始内容的主要搜索引擎。
#
# - **非结构化 IO：** 用于内容分块，便于管理非结构化数据以实现更高效的处理。
#
# 首先我要给所需要的工具设置好API 密钥
#
# 您可以到[`这里`](https://app.agentops.ai/signin)从 AgentOps 获取 **免费的** API 密钥

# %%
import os
from getpass import getpass

# 输入 AgentOps API 密钥
agentops_api_key = getpass('请输入您的 API 密钥: ')
os.environ["AGENTOPS_API_KEY"] = agentops_api_key

# %% [markdown]
# 您可以到[`这里`](https://www.firecrawl.dev/)从 Firecrawl 获取 **免费** API 密钥

# %%
firecrawl_api_key = getpass('Enter your API key: ')
os.environ["FIRECRAWL_API_KEY"] = firecrawl_api_key

# %% [markdown]
# Firecrawl 是一个强大的工具，可简化网页抓取和清理网页内容的过程。在本节中，我们将从 CAMEL AI 网站上的特定帖子中抓取内容作为示例。

# %%
from camel.loaders import Firecrawl

firecrawl = Firecrawl()

# 从指定的 URL 抓取并清理内容
response = firecrawl.scrape(
    url="https://www.camel-ai.org/"
)

print(response["markdown"])
# Out:
# We are Building A HuggingFace-like Community for AI Agent Builders
#
# # Building Multi-Agent  Systems for Data Generation\_
#
# CAMEL-AI is a open-source community for finding the scaling laws of agents for data generation, world simulation, task automation.
#
# [Get Started](https://github.com/camel-ai/camel) [Join Community\\
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67a607078c6a8fb13607cc40_call.png)](https://discord.com/invite/CNcNpquyDc)
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/679b8e160241a343d442a17d_world%20simulation.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/679b98f0969e2c97885eb7cd_task%20automation.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/679b99000e3fbe69fb86197f_data%20generation.png)
#
# What's New on
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67ea93c3c0248e938bc895e7_birthday.png)\\
# **🎉 Happy CAMEL-AI's 2nd Birthday** \\
# \\
# We’re kicking off our birthday week with 5 straight days of new launches.](https://www.camel-ai.org/launchweek-environments) [**🦉OWL** \\
# **Optimized Workforce Learning** for General Multi-Agent Assistance in Real-World Task Automation](https://github.com/camel-ai/owl) [**🐉 Loong Project** \\
# Build the infrastructure for training reasoning abilities of LLM agents in different domains. **( We are calling for Contribution! )**](https://www.camel-ai.org/research) [**🛠️ MCP with CAMEL** \\
# Build Agents & Multi-agent System with CAMEL & Anthropic Model Context Protocol (MCP) **coming soon...**](https://www.camel-ai.org/mcp)
#
# OUR Mission
#
# ## We Are Finding  the Scaling Laws of Agents
#
# We believe that studying these agents on a large scale offers valuable insights into their behaviors, capabilities, and potential risks.
#
# [Join Research Meeting](https://discord.camel-ai.org/)
#
# ##### Number of  Agents
#
# [Role Playing](https://docs.camel-ai.org/cookbooks/basic_concepts/create_your_first_agents_society.html) [Workforce](https://docs.camel-ai.org/key_modules/workforce.html) [OASIS](https://github.com/camel-ai/oasis)
#
# ##### Enviornment of  Agents
#
# [CRAB](https://github.com/camel-ai/crab) [Benchmarks](https://github.com/camel-ai/camel/tree/master/camel/benchmarks) [LOONG](https://www.camel-ai.org/research)
#
# ##### Ability of  Evolution
#
# [Data Generation](https://docs.camel-ai.org/key_modules/datagen.html) [Graph RAG](https://docs.camel-ai.org/cookbooks/advanced_features/agents_with_graph_rag.html) [Fine-Tuning Post-Training](https://docs.camel-ai.org/cookbooks/data_generation/sft_data_generation_and_unsloth_finetuning_Qwen2_5_7B.html)
#
# ##### What's Next?
#
# ###### Research with Us
#
# Rigorous research takes time and resources. **We are a community-driven research collective with 100+ researchers exploring the frontier research of Multi-agent Systems**. Join our ongoing projects or test new ideas with us, [reach out via email](mailto:camel-ai@eigent.ai?subject=Research%20Collaboration) for more information.
#
# ###### Join our Open Source Community
#
# We value every contribution, from new features to bug fixes. Projects at CAMEL evolves around enhancing infrastructure, improving documentation, and implementing research ideas. Check out our [Contributing Guidelines](https://github.com/camel-ai/camel/wiki/Contributing-Guidlines) on GitHub.
#
# #### Read Our Research Projects
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b773e0e3fbe69fb604af2_camel.jpg)\\
# ![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b7d047282e0a9ae21efd0_camel.png)**CAMEL: Communicative Agents for "Mind" Exploration of Large Language Model Society** \\
# \\
# arXiv\\
# \\
# 2 Nov 2023](https://github.com/camel-ai/camel)
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b783887adc05bcf1fcfca_2407.01511_page-0001.jpg)\\
# ![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b7cfefdeced8fc68404a0_size%3Dxl%2C%20state%3Dtransparent.svg)**CRAB: Cross-environment Agent Benchmark for Multimodal Language Model Agents** \\
# \\
# arXiv\\
# \\
# 18 Oct 2024](https://github.com/camel-ai/crab)
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b78a96171c99f232fb624_2402.04559_page-0001.jpg)\\
# ![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b7cf42363ee1bb52abf84_trust.svg)**Can Large Language Model Agents Simulate Human Trust Behavior?** \\
# \\
# arXiv\\
# \\
# 1 Nov 2024](https://github.com/camel-ai/agent-trust)
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b7902b59b980127cab812_2411.11581_page-0001.jpg)\\
# ![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/679b7cb5cb09b3c622c0ac94_size%3Dxl%2C%20style%3Dtransparent.svg)**OASIS: Open Agent Social Interaction Simulations with One Million Agents** \\
# \\
# arXiv\\
# \\
# 26 Nov 2024](https://github.com/camel-ai/oasis)
#
# Our Academic Partners
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b8144f8c6910e58f541f_kaust.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b3977cd5d17016062c0f_image%20144.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b4bbeeda8b03637ae3ea_Frame%2071.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b4bb7ae54c8ae13516fc_Frame%201116606981.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b4bb71d79cb1e11c3a5e_Frame%201116606982.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b4bb6891da579a557618_Frame%201116606983.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b4bcfb29fd35ed27b475_Frame%201116606985.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b814a4b66c816bc09976_chicago.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b83be01ea35620079414_penn%20state.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b8152fc26dfc78f9616a_michigan.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b814e7465fcdb002dac1_santa%20fe.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b8bc08e6f84c6b0934d7_cmu.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4b8bcba10eef3c47e7e4f_utoyo.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4babd77a906f04725128e_fudan.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4babd4d1f9e6f601b1d7b_nus.png)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4babcc472b278f4eb748a_ydney.png)
#
# What can camel do?
#
# ## You Can Use CAMEL to Build
#
# CAMEL is the world's first multi-agent system. It is designed to be data-driven, stateful, and agent-friendly.
#
# 1\. Data Generation
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4c69e5a561337e25556a3_Chain%20of%20Thought.png)\\
# Chain-of-Thought (CoT) Data Generation\\
# \\
# The Chain of Thought (CoT) data generation module implements a sophisticated system for generating high-quality reasoning paths through chat agent interactions. It combines several advanced algorithms to produce and validate reasoning chains.](https://github.com/camel-ai/camel/blob/master/camel/datagen/cot_datagen.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4c69dff0d5d5f0e08c6e9_Self%20Improving.png)\\
# Self-Instruct: Instruction Generation\\
# \\
# The Self-Instruct module implements a pipeline for generating and managing machine-generated instructions for tasks. It combines human-written seed instructions with machine-generated ones to create diverse, high-quality task instructions, while ensuring quality through configurable filtering mechanisms.](https://github.com/camel-ai/camel/tree/master/camel/datagen/self_instruct) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4c3ddc3f4cda3ab114833_Multi-hop.png)\\
# Source2Synth: Multi-hop Question-Answer Generation\\
# \\
# Source2Synth is a sophisticated data generation system designed to create multi-hop question-answer pairs from source text data. It implements a pipeline that processes raw text, extracts information pairs, and generates complex, multi-hop reasoning questions with configurable complexity thresholds.](https://github.com/camel-ai/camel/tree/master/camel/datagen/source2synth) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4c69d9b84b8a5bd9a68b0_Self%20Instruction.png)\\
# Self-Improving Chain-of-Thought (CoT) Data Generation\\
# \\
# The Self-Improving CoT Data Generation pipeline implements an iterative approach to generate and improve reasoning traces for problem-solving tasks. This implementation is based on the methodology of self-taught reasoning, where an AI agent learns to improve its reasoning process through self-evaluation and feedback.](https://github.com/camel-ai/camel/blob/master/camel/datagen/self_improving_cot.py)
#
# 2\. Task Automation
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4a993d5c5cbf97cf9f79e_Role%20Playing.png)\\
# Role Playing\\
# \\
# Role Playing is a unique cooperative agent framework of CAMEL. Through this framework, agents in CAMEL overcome numerous challenges, such as _role flipping_, _assistant repeats instructions_, _flake replies_, _infinite loop of messages_, and _conversation termination conditions._](https://github.com/camel-ai/camel/blob/master/camel/societies/role_playing.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4a993cb2ea5c17a3f4407_Workforce.png)\\
# Workforce\\
# \\
# Workforce is a system where multiple agents work together to solve tasks. By using Workforce, users can quickly set up a multi-agent task solving system with customized configurations. In this section, we will give a brief view on the architecture of workforce, and how you can configure and utilize it to solve tasks.](https://github.com/camel-ai/camel/tree/master/camel/societies/workforce) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b4a993edf10a44221c0eb3_RAG%20Pipeline.png)\\
# RAG Pipeline\\
# \\
# A Retrieval-Augmented Generation (RAG) pipeline enhances task automation by integrating information retrieval with generative AI models. It retrieves relevant data from external sources to inform the AI’s responses, ensuring outputs are accurate and contextually relevant. This approach reduces inaccuracies and adapts to specific domains, improving efficiency in automated workflows.](https://docs.camel-ai.org/cookbooks/advanced_features/agents_with_rag.html)
#
# 3\. World Simulation
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b468cdda2cccf3e5b9a0d7_World%20Simulation.png)
#
# OASIS: Open Agent Social Interaction Simulations with One Million Agents.
#
# OASIS is a scalable, open-source social media simulator that integrates large language models with rule-based agents to realistically mimic the behavior of up to one million users on platforms like Twitter and Reddit. It's designed to facilitate the study of complex social phenomena such as information spread, group polarization, and herd behavior, offering a versatile tool for exploring diverse social dynamics and user interactions in digital environments.
#
# [Learn More](https://github.com/camel-ai/oasis)
#
# camel community
#
# ## Join CAMEL to Build Agentic World Together !
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/675823a5ed3bcba3506bea7d_researchtop.png)\\
# **Research with Us**](https://www.camel-ai.org/research) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/675823aced278d8b0aa014f4_amabassadortop.png)\\
# **CAMEL  Ambassador Program**](https://www.camel-ai.org/ambassador) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/675823ac8c46c2e5e72b306a_buildtop.png)\\
# **Build with CAMEL**](https://github.com/camel-ai/camel)
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b5ca465544ff7097c9663d_IMG_0746.JPG)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b5cae1f9b4da27021647f1_DSC00681.jpg)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b5ca4609fb27a15436f772_IMG_0747.JPG)![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b5cae14668694eb0d249a0_DSC00344.jpg)
#
# Tech stack
#
# ## Create Powerful Agentic Application with   Our Tools
#
# Agent
#
# (Single-agent)
#
# [Chat Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/chat_agent.py) [Critic Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/critic_agent.py) [Deductive Reasoner Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/deductive_reasoner_agent.py) [Embodied Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/embodied_agent.py) [Knowledge Graph Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/knowledge_graph_agent.py) [MultiHop Generator Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/multi_hop_generator_agent.py) [Programmed Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/programmed_agent_instruction.py) [Role Assignment Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/role_assignment_agent.py) [Search Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/search_agent.py) [Task Agent](https://github.com/camel-ai/camel/blob/master/camel/agents/task_agent.py)
#
# Agent Societies
#
# (Multi-agent)
#
# [Role Playing](https://github.com/camel-ai/camel/blob/master/camel/societies/role_playing.py) [Workforce](https://github.com/camel-ai/camel/tree/master/camel/societies/workforce)
#
# Data Generation
#
# [**Self-Improving CoT Data Generation**](https://github.com/camel-ai/camel/blob/master/camel/datagen/self_improving_cot.py) [**Chain of Thought (CoT) Data Generation**](https://github.com/camel-ai/camel/blob/master/camel/datagen/cot_datagen.py) [Self-Instruct: Instruction Generation](https://github.com/camel-ai/camel/blob/master/camel/datagen/self_instruct/self_instruct.py) [**Source2Synth: Multi-hop Question-Answer Generation**](https://github.com/camel-ai/camel/tree/master/camel/datagen/source2synth)
#
# Models
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7d51c2bd1ee267cefc_Open%20AI.png)](https://github.com/camel-ai/camel/blob/master/camel/models/openai_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7bc1a90c606231b315_Frame%2050.png)](https://github.com/camel-ai/camel/blob/master/camel/models/mistral_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7c1abc9b5836faa4a9_Frame%201116606939.png)](https://github.com/camel-ai/camel/blob/master/camel/models/moonshot_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7baffe7dfcb4064af9_Frame%201116606940.png)](https://github.com/camel-ai/camel/blob/master/camel/models/anthropic_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7bbe1dfe7b3c99a462_Frame%201116606937.png)](https://github.com/camel-ai/camel/blob/master/camel/models/gemini_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67c8775588b13aac4ae7fab9_image%20(1).png)](https://github.com/camel-ai/camel/blob/master/camel/models/yi_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7da94945297e606dd6_Frame%201116606941.png)](https://github.com/camel-ai/camel/blob/master/camel/models/qwen_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7c84b4acb8eea56d2a_Frame%201116606942.png)](https://github.com/camel-ai/camel/blob/master/camel/models/deepseek_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7c07b4c2815820a4ce_Frame%201116606943.png)](https://github.com/camel-ai/camel/blob/master/camel/models/zhipuai_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67c8775526cb6dab0c779a83_image.png)](https://github.com/camel-ai/camel/blob/master/camel/models/internlm_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7bd7af9e06369fdedb_Frame%201116606945.png)](https://github.com/camel-ai/camel/blob/master/camel/models/reka_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7c3c3c44fc26e80c11_Frame%201116606946.png)](https://github.com/camel-ai/camel/blob/master/camel/models/samba_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7f14eb2a7f0fc838f2_Frame%201116606953.png)](https://github.com/camel-ai/camel/blob/master/camel/models/nvidia_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7b0a0b7391905a2be3_Frame%201116606947.png)](https://github.com/camel-ai/camel/blob/master/camel/models/groq_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7c3ed2ca1043f45af1_Frame%201116606948.png)](https://github.com/camel-ai/camel/blob/master/camel/models/ollama_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7cfacfc75e792afb90_Frame%201116606949.png)](https://github.com/camel-ai/camel/blob/master/camel/models/vllm_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7ceff2002c12076b3a_Frame%201116606950.png)](https://github.com/camel-ai/camel/blob/master/camel/models/togetherai_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7f14eb2a7f0fc838c8_Frame%201116606951.png)](https://github.com/camel-ai/camel/blob/master/camel/models/litellm_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7c4abb8e76102d4652_Frame%201116606952.png)](https://github.com/camel-ai/camel/blob/master/camel/models/sglang_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32b7daffe7dfcb4064c83_Frame%201116606954.png)](https://github.com/camel-ai/camel/blob/master/camel/models/aiml_model.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b32effe6bcd6416d4c0913_Frame%201116606955.png)](https://github.com/camel-ai/camel/blob/master/camel/models/cohere_model.py)
#
# Tools
#
# [arXiv Toolkit](https://github.com/camel-ai/camel/blob/master/camel/toolkits/arxiv_toolkit.py) [Ask News Toolkit](https://github.com/camel-ai/camel/blob/master/camel/toolkits/ask_news_toolkit.py) [Code Execution](https://github.com/camel-ai/camel/blob/master/camel/toolkits/code_execution.py) [Dalle](https://github.com/camel-ai/camel/blob/master/camel/toolkits/dalle_toolkit.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b3581469a54c9b495e72cb_Frame%201116606977.png)\\
# Dappier](https://github.com/camel-ai/camel/blob/master/camel/toolkits/dappier_toolkit.py) [Data Commons](https://github.com/camel-ai/camel/blob/master/camel/toolkits/data_commons_toolkit.py) [Function tool](https://github.com/camel-ai/camel/blob/master/camel/toolkits/function_tool.py) [Github](https://github.com/camel-ai/camel/blob/master/camel/toolkits/github_toolkit.py) [Google Map](https://github.com/camel-ai/camel/blob/master/camel/toolkits/google_maps_toolkit.py) [Google Scholar](https://github.com/camel-ai/camel/blob/master/camel/toolkits/google_scholar_toolkit.py) [Linkedin](https://github.com/camel-ai/camel/blob/master/camel/toolkits/linkedin_toolkit.py) [Math](https://github.com/camel-ai/camel/blob/master/camel/toolkits/math_toolkit.py) [Meshy](https://github.com/camel-ai/camel/blob/master/camel/toolkits/meshy_toolkit.py) [MinerU](https://github.com/camel-ai/camel/blob/master/camel/toolkits/mineru_toolkit.py) [NetworkX](https://github.com/camel-ai/camel/blob/master/camel/toolkits/networkx_toolkit.py) [Notion](https://github.com/camel-ai/camel/blob/master/camel/toolkits/notion_toolkit.py) [Open API](https://github.com/camel-ai/camel/blob/master/camel/toolkits/open_api_toolkit.py) [Open BB](https://github.com/camel-ai/camel/blob/master/camel/toolkits/openbb_toolkit.py) [Reddit](https://github.com/camel-ai/camel/blob/master/camel/toolkits/reddit_toolkit.py) [Retrieval](https://github.com/camel-ai/camel/blob/master/camel/toolkits/retrieval_toolkit.py) [Search](https://github.com/camel-ai/camel/blob/master/camel/toolkits/search_toolkit.py) [Semantic Scholar](https://github.com/camel-ai/camel/blob/master/camel/toolkits/semantic_scholar_toolkit.py) [Slack](https://github.com/camel-ai/camel/blob/master/camel/toolkits/slack_toolkit.py) [Stripe](https://github.com/camel-ai/camel/blob/master/camel/toolkits/stripe_toolkit.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b357891f084fbde032f273_Frame%201116606974.png)\\
# Sympy](https://github.com/camel-ai/camel/blob/master/camel/toolkits/sympy_toolkit.py) [X (Twitter)](https://github.com/camel-ai/camel/blob/master/camel/toolkits/twitter_toolkit.py) [Video](https://github.com/camel-ai/camel/blob/master/camel/toolkits/video_toolkit.py) [Weather](https://github.com/camel-ai/camel/blob/master/camel/toolkits/weather_toolkit.py) [WhatsApp](https://github.com/camel-ai/camel/blob/master/camel/toolkits/whatsapp_toolkit.py)
#
# Memories
#
# [Long Term Memory](https://github.com/camel-ai/camel/tree/master/camel/memories) [Short Term Memory](https://github.com/camel-ai/camel/tree/master/camel/memories)
#
# Storage
#
# Key Value Storage :
#
# [In Memory](https://github.com/camel-ai/camel/blob/master/camel/storages/key_value_storages/in_memory.py) [JSON](https://github.com/camel-ai/camel/blob/master/camel/storages/key_value_storages/json.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33834c89aad38145976f6_Frame%201116606963.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/key_value_storages/redis.py)
#
# Graph Storage :
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b338b4b45d8db1a91a6e7c_Frame%201116606956.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/graph_storages/nebula_graph.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b3383346bb933b47d44ec3_Frame%201116606957.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/graph_storages/neo4j_graph.py)
#
# Object Storage :
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b3383446bb933b47d44f18_Frame%201116606958.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/object_storages/amazon_s3.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b338b45340d2bfbcb76c2d_Frame%201116606959.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/object_storages/azure_blob.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b3383461a120c6b51a1ea2_Frame%201116606960.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/object_storages/google_cloud.py)
#
# Vector DB Storage :
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33834548fb08260a4ae99_Frame%201116606961.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/vectordb_storages/qdrant.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b338345a9d9ad2bda2a58b_Frame%201116606962.png)](https://github.com/camel-ai/camel/blob/master/camel/storages/vectordb_storages/milvus.py)
#
# Benchmarks
#
# [GAIA](https://github.com/camel-ai/camel/blob/master/camel/benchmarks/gaia.py) [RAG Bench](https://github.com/camel-ai/camel/blob/master/camel/benchmarks/ragbench.py) [API Bank](https://github.com/camel-ai/camel/blob/master/camel/benchmarks/apibank.py) [API Bench](https://github.com/camel-ai/camel/blob/master/camel/benchmarks/apibench.py) [Nexus](https://github.com/camel-ai/camel/blob/master/camel/benchmarks/nexus.py)
#
# Interpreters
#
# [Docker](https://github.com/camel-ai/camel/blob/master/camel/interpreters/docker_interpreter.py) [E2B](https://github.com/camel-ai/camel/blob/master/camel/interpreters/e2b_interpreter.py) [Internal Python](https://github.com/camel-ai/camel/blob/master/camel/interpreters/internal_python_interpreter.py) [Interpreter Error](https://github.com/camel-ai/camel/blob/master/camel/interpreters/interpreter_error.py) [Ipython](https://github.com/camel-ai/camel/blob/master/camel/interpreters/ipython_interpreter.py) [Subprocess](https://github.com/camel-ai/camel/blob/master/camel/interpreters/subprocess_interpreter.py)
#
# Data Loaders
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33fa433f64ff08493f4cd_Frame%201116606964.png)](https://github.com/camel-ai/camel/blob/master/camel/loaders/mineru_extractor.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33fa473756cc0123635dc_Frame%201116606965.png)](https://github.com/camel-ai/camel/blob/master/camel/loaders/chunkr_reader.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33fa4cc1937c720ba4a1a_Frame%201116606967.png)](https://github.com/camel-ai/camel/blob/master/camel/loaders/apify_reader.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33fcb542401aca3993444_Frame%201116606966.png)](https://github.com/camel-ai/camel/blob/master/camel/loaders/firecrawl_reader.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33fa4cf7f66c5f13856f4_Frame%201116606968.png)](https://github.com/camel-ai/camel/blob/master/camel/loaders/jina_url_reader.py)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b33fa4f208374fc346eca3_Frame%201116606969.png)](https://github.com/camel-ai/camel/blob/master/camel/loaders/unstructured_io.py)[Panda Reader](https://github.com/camel-ai/camel/blob/master/camel/loaders/panda_reader.py)
#
# Retrievers
#
# [Auto Retriever](https://github.com/camel-ai/camel/blob/master/camel/retrievers/auto_retriever.py) [BM25 Retriever](https://github.com/camel-ai/camel/blob/master/camel/retrievers/bm25_retriever.py) [Cohere Rerank Retriever](https://github.com/camel-ai/camel/blob/master/camel/retrievers/cohere_rerank_retriever.py) [Vector Retriever](https://github.com/camel-ai/camel/blob/master/camel/retrievers/vector_retriever.py) [Hybird Retriever](https://github.com/camel-ai/camel/blob/master/camel/retrievers/hybrid_retrival.py)
#
# Run Time
#
# [API](https://github.com/camel-ai/camel/blob/master/camel/runtime/api.py) [Configs](https://github.com/camel-ai/camel/blob/master/camel/runtime/configs.py) [Docker Runtime](https://github.com/camel-ai/camel/blob/master/camel/runtime/docker_runtime.py) [LLM Guard Runtime](https://github.com/camel-ai/camel/blob/master/camel/runtime/llm_guard_runtime.py) [Remote HTTP Runtime](https://github.com/camel-ai/camel/blob/master/camel/runtime/remote_http_runtime.py)
#
# Human in the Loop
#
# [Human in the Loop Toolkit](https://github.com/camel-ai/camel/blob/master/camel/toolkits/human_toolkit.py)
#
# camel use cases
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/679b91a4dce8384d00b32338_built%20with%20camel.svg)
#
# ## Built with CAMEL
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67a10df0c2bf2d977acb803d_eigentbot.png)\\
# \\
# ****One Bot, Every Answers**** \\
# \\
# EigentBot deploys an AI-powered community manager in seconds! - Seamlessly integrate with web links, files, Notion, GitHub, LinkedIn, and more. - Prioritizing privacy, we support local model deployment. - With one-click, get your bot running in just 3 seconds!](https://www.bot.eigent.ai/) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67a11364f0eb0b0312b71648_mistral.png)\\
# \\
# ****Frontier AI in Your Hands**** \\
# \\
# Mistral AI focuses on creating efficient, cost-effective AI models that require fewer computational resources. The company offers both free open-source models and commercial API-only models, aiming to democratize AI technology](https://mistral.ai/) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67a1136458e3f3b1363fe4a7_sambanova.png)\\
# \\
# ****The World's Fastest AI Inference**** \\
# \\
# It offers enterprise-scale AI platforms, including hardware and software, designed for generative AI. SambaNova's products feature proprietary chip designs and full-stack approaches, enabling efficient deployment of complex AI applications across various industries.](https://docs.sambanova.ai/cloud/docs/integrations/camelAI) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67a113646442b12052f445e7_drant.png)\\
# \\
# ****High-Performance Vector Search**** \\
# \\
# Qdrant offers a high-performance, open-source vector search database designed to power next-generation AI applications. It enables efficient similarity searches for high-dimensional data, facilitating tasks like matching, searching, and recommending.](https://qdrant.tech/documentation/frameworks/camel/) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67530ba4dbdf6495240b8177_composio_black_font.svg)\\
# \\
# ****Production Ready Toolset for AI Agents**** \\
# \\
# Empower your AI agents with Composio - a platform for managing and integrating tools with LLMs & AI agents using Function Calling.](https://docs.composio.dev/framework/camelai) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67a113534e1d91f5638760f7_firecrawl.png)\\
# \\
# ****Turn Websites into LLM-ready Data**** \\
# \\
# Firecrawl turns entire websites into clean, LLM-ready markdown or structured data. Scrape, crawl and extract the web with a single API.](https://docs.firecrawl.dev/integrations/camelai) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b338345a9d9ad2bda2a58b_Frame%201116606962.png)\\
# \\
# ****The High-Performance**  **Vector Database Built for Scale**** \\
# \\
# Milvus is an open-source vector database built for GenAI applications. Install with pip, perform high-speed searches, and scale to tens of billions of vectors with minimal performance loss.](https://docs.firecrawl.dev/integrations/camelai) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67530c4eb2c1e3b62a195fe3_ChatDev-AI-virtual-coding-company%201.jpg)\\
# \\
# ****Communicative Agents for Software Development**** \\
# \\
# Create Customized Software using Natural Language Idea (through LLM-powered Multi-Agent Collaboration)](https://github.com/OpenBMB/ChatDev/tree/main/camel) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67b36a8e06d971a678c52956_Screenshot%202025-02-17%20at%2016.57.37.png)\\
# \\
# ****Towards Better LLM-based Evaluators through Multi-Agent Debate**** \\
# \\
# ChatEval is a scalable evaluation framework that combines automated metrics and human judgments to benchmark and improve chatbots’ dialogue quality.](https://arxiv.org/abs/2308.07201) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/672e30e1efcfb2c761c6f55c_5u5oSqM0aqTzrOOkuB2HX2C3C0.avif)\\
# \\
# ****AI Accuracy , Delivered**** \\
# \\
# Improve LLM accuracy by 50% or more with Log10's AutoFeedback. Scale human perspective by 1000x using fine-tuned models and synthetic data.](https://github.com/log10-io/log10/blob/main/src/log10/agents/camel.py) [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/673227a1613faf3992973fae_1731259445867%201.png)\\
# \\
# ****AI-powered interview co-pilot.**** \\
# \\
# AI Geometric is your AI-powered interview co-pilot, transforming job preparation from a solo task into an immersive, multi-dimensional experience.](https://www.linkedin.com/posts/aigeometric_ai-interviewpreparation-careerdevelopment-activity-7261428422516555776-MtaK?utm_source=share&utm_medium=member_desktop&rcm=ACoAAChHluEB9xRwkjiJ6VSAzqM2Y-U4NI2sKGY)
#
# Testimonials
#
# ## **Success Stories with CAMEL**
#
# “The thing that I find really interesting with this is that it’s an unbelievably good way to make synthetic data. If you’re trying to create any sort of customer service or chatbot agent that communicates with the public, this allows you to make synthetic data for training and fine-tuning.”
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/66716e213e9e2a5081b55256_jtlg8bxr0w6quu157b7f_400x400%20(1).png)
#
# ###### Sam Witteveen
#
# Co-founder @ Red Dragon AI
#
# "The CAMEL AI “Domain Expert” dataset, comprising 25,000 conversations between two GPT 3.5 Turbo agents was used as part of the training data for Teknium’s OpenHermes model and the Microsoft Phi model"
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/666822291d4453b7f7b9def6_86200048.jpeg)
#
# ###### Valory
#
# Open-source framework
#
# "Guohao Li, who designed Camel, highlights the potential of multi-agent systems to bypass traditional AI limitations, enabling tasks like phishing email generation and cyber bug development."
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/6661945978093c44ac8aa993_unnamed%20(1).jpg)
#
# ###### The Economist
#
# Newspaper
#
# “The essence of Camel lies in its prompt engineering, i.e., inception prompting. The prompts are actually carefully defined to assign roles, prevent flipping roles, prohibit harm and false information, and encourage consistent conversation.”
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/667531572b2dc524f379bc52_1713521452801.jpeg)
#
# ###### **Sophia Yang, Ph.D.**
#
# Head of Developer Relations @ Mistral AI
#
# MPT-30B-Chat is a chatbot-like model for dialogue generation. It was built by finetuning MPT-30B and trained on 19.54% Camel-AI sourced data
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/666824e69aca25f4f96026d0_channels4_profile.jpg)
#
# ###### Databricks
#
# The Data and AI Company
#
# "This innovative concept is set to redefine the way AI agents interact with each other and, in doing so, revolutionize the realm of conversational AI."
#
# ![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/6662b9301f37190f7a2e12b8_1516275463332.jpeg)
#
# ###### Yogesh Haribhau Kulkarni
#
# AI Advisor
#
# camel blog
#
# ## **What's new?**
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/67ea8b8a242e20aa739b7164_environment.PNG.png)\\
# **Scaling Environments for Agents** \\
# \\
# March 31, 2025](https://www.camel-ai.org/blogs/scaling-environments-for-agents)
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/67e9c5776fbc2bf15e3750fd_Scaling.jpg)\\
# **The Mission at CAMEL-AI.org: Finding the Scaling Laws of Agents** \\
# \\
# Oct 3, 2024](https://www.camel-ai.org/blogs/mission-at-camel-ai-org-finding-the-scaling-laws-of-agents)
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/6722522165574c076436d084_Release%20Notes%20Oct%20(3).jpg)\\
# **CAMEL Release notes \[Sprint 12\]** \\
# \\
# Nov 4, 2024](https://www.camel-ai.org/blogs/camel-release-notes-sprint-12)
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/66cec734736f9095d2f7388e_agent%20101.jpg)\\
# **Getting Started with Agent Tool Usage - CAMEL 101** \\
# \\
# Aug 27, 2024](https://www.camel-ai.org/blogs/tool-usage)
#
# [![](https://cdn.prod.website-files.com/6659a155491a54a40551bd7f/6734a675d10b1f5fff3eff11_Release%20Notes%20Oct.jpg)\\
# **CRAB: Cross-environment Agent Benchmark for Multimodal Language Model Agents** \\
# \\
# Aug 9, 2024](https://www.camel-ai.org/blogs/crab)
#
# Get started
#
# ## Build your multi-agent system today
#
# Get started by joining our community
#
# [Join Discord](http://discord.camel-ai.org/)
#
# Get Updates Now
#
# Thank you! Your submission has been received!
#
# Oops! Something went wrong while submitting the form.
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/6686afd48a4c823499baa2e7_Camel%20Logo%20Long.png)](https://www.camel-ai.org/)
#
# Finding the Scaling Laws of Agents
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/6659a155491a54a40551bd92_mail.svg)](mailto:camel-ai@eigent.ai?subject=Hi%20CAMEL-AI%20Team)
#
# [![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/6675648577704e5e10bcdc87_Discord.svg)](http://discord.camel-ai.org/)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/66756482a95ea32bb2904c70_Github.svg)](https://github.com/camel-ai/camel)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/6736730d49b99ccd0c366086_Linkedin.svg)](https://www.linkedin.com/company/camel-ai-org/)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/673673125c8feebf7af520bd_X.svg)](https://x.com/CamelAIOrg)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/673672ff21614854f86a459c_youtube-color_svgrepo.com.svg)](https://www.youtube.com/@CamelAI)[![](https://cdn.prod.website-files.com/6659a154491a54a40551bc78/67a116915d700d8cacc1569f_free-reddit-logo-icon-2436-thumb.png)](https://www.reddit.com/r/CamelAI/)
#
# Products
#
# [EigentBot](https://bot.eigent.ai/) [EigentLab (Coming Soon)](https://www.camel-ai.org/#)
#
# RESEARCH
#
# [AgentTrust](https://agent-trust.camel-ai.org/) [CAMEL](https://github.com/camel-ai/camel) [CRAB](https://github.com/camel-ai/crab) [OASIS](https://github.com/camel-ai/oasis) [OWL](https://github.com/camel-ai/owl)
#
# RESOURCES
#
# [Home](https://www.camel-ai.org/) [Blogs](https://www.camel-ai.org/blogs) [Community](https://www.camel-ai.org/community) [Documents](https://docs.camel-ai.org/) [MCP](https://www.camel-ai.org/mcp)
#
# Copyright © 2024 Eigent AI - All Rights Reserved.

# %% [markdown]
# - **🛠️ 使用 CAMEL 的 RAG 和 Firecrawl 进行 Web 信息检索**
#
# 在本节中，我们将演示如何使用 Camel 的 RAG 模型从 URL 列表中检索相关信息。这对于聚合和分析来自多个来源的数据特别有用。
#
# 首先我们定义一个检索方法：

# %%
from camel.retrievers import AutoRetriever
from camel.toolkits import FunctionTool, SearchToolkit
from camel.types import ModelPlatformType, ModelType, StorageType
from camel.embeddings import SentenceTransformerEncoder

def retrieve_information_from_urls(urls: list[str], query: str) -> str:
    r"""根据给定的查询从 URL 列表中检索相关信息。

    此函数使用 `Firecrawl` 工具从提供的 URL 抓取内容，然后使用 CAMEL 的 `AutoRetriever` 根据查询从抓取的内容中检索最相关的信息。

    参数:
        urls (list[str]): 要抓取内容的 URL 列表。
        query (str): 用于搜索相关信息的查询字符串。

    返回:
        str: 根据查询检索到的最相关信息。

    示例:
        >>> urls = ["https://example.com/article1", "https://example.com/
        article2"]
        >>> query = "最新的人工智能进展"
        >>> result = retrieve_information_from_urls(urls, query)
    """
    aggregated_content = ''

    # 从每个 URL 抓取并聚合内容
    for url in urls:
        scraped_content = Firecrawl().scrape(url)
        aggregated_content += scraped_content["markdown"]

    # 设置一个带有本地存储和 Mistral AI 嵌入模型的向量检索器
    auto_retriever = AutoRetriever(
        vector_storage_local_path="local_data",
        storage_type=StorageType.QDRANT,
        embedding_model=SentenceTransformerEncoder(),
    )

    # 根据查询检索最相关的信息
    # 您可以根据需要调整 top_k 和 similarity_threshold 的值
    retrieved_info = auto_retriever.run_vector_retriever(
        query=query,
        contents=aggregated_content,
        top_k=3,
        similarity_threshold=0.5,
    )

    return retrieved_info

# %% [markdown]
# 让我们通过收集有关 2024 年奥运会的一些信息来测试检索功能。第一次运行可能需要大约 50 秒，因为它需要构建本地向量数据库。

# %%
retrieved_info = retrieve_information_from_urls(
    query="哪个国家在2024年奥运会上获得了最多的金牌？",
    urls=[
        "https://www.nbcnews.com/sports/olympics/united-states-china-gold-medals-rcna166013",
    ],
)

print(retrieved_info)

# %% [markdown]
# - 📹 **使用 AgentOps 监控 AI 代理**

# %%
import agentops
agentops.init(default_tags=["CAMEL cookbook"])

# %% [markdown]
# CAMEL 的一个强大功能是它能够从文本数据构建和存储知识图谱。这很方便我们对数据中的关系进行高级分析和可视化。
#
# 首先我们定义一个函数用于处理输入文本以创建和提取节点和关系，并将其作为知识图谱添加到Neo4j数据库中。

# %%
from camel.storages import Neo4jGraph
from camel.loaders import UnstructuredIO
from camel.agents import KnowledgeGraphAgent

def knowledge_graph_builder(text_input: str) -> None:
    r"""从提供的文本构建并存储知识图谱。

    此函数处理输入文本以创建和提取节点和关系，
    然后将其作为知识图谱添加到Neo4j数据库中。

    参数：
        text_input (str): 用于构建知识图谱的输入文本。

    返回：
        graph_elements: 知识图谱代理生成的图形元素。
    """

    # 设置Neo4j实例
    n4j = Neo4jGraph(
        url="Your_URL",
        username="Your_Username",
        password="Your_Password",
    )

    # 初始化实例
    uio = UnstructuredIO()
    kg_agent = KnowledgeGraphAgent(model=model)

    # 从提供的文本创建一个元素
    element_example = uio.create_element_from_text(text=text_input, element_id="001")

    # 使用知识图谱代理提取节点和关系
    graph_elements = kg_agent.run(element_example, parse_graph_elements=True)

    # 将提取的图形元素添加到Neo4j数据库
    n4j.add_graph_elements(graph_elements=[graph_elements])

    return graph_elements

# %% [markdown]
# 然后我们设置我们的RolePlaying,AI 代理在其中交互以使用各种工具完成任务。我们将指导助理代理对 2024 年巴黎奥运会的土耳其射击运动员进行全面研究。
#
# <img src="img/image10.png" alt="image" width="800">

# %% [markdown]
# 导入模块及定义我们的任务：

# %%
from typing import List

from colorama import Fore

from camel.agents.chat_agent import FunctionCallingRecord
from camel.societies import RolePlaying
from camel.utils import print_text_animated

task_prompt = """对2024年巴黎奥运会的土耳其射手进行全面研究，为我写一份报告，然后为报告创建知识图谱。
您应该首先使用搜索工具获取相关的URL，然后使用检索工具通过提供URL列表来获取检索到的内容，最后使用工具构建知识图谱以完成任务。
不要进行其他操作。"""

# %% [markdown]
# 我们将为助理代理配置用于数学计算、Web 信息检索和知识图谱构建的工具。

# %%
retrieval_tool = FunctionTool(retrieve_information_from_urls)
search_tool = FunctionTool(SearchToolkit().search_duckduckgo)
knowledge_graph_tool = FunctionTool(knowledge_graph_builder)

tool_list = [
    retrieval_tool,
    search_tool,
    knowledge_graph_tool,
]

assistant_model_config = dict(
    tools=tool_list,
    temperature=0.0,
)

# 初始化RolePlaying
role_play_session = RolePlaying(
    assistant_role_name="CAMEL Assistant",
    user_role_name="CAMEL User",
    assistant_agent_kwargs=dict(
        model=model,
        tools=tool_list,
    ),
    user_agent_kwargs=dict(model=model),
    task_prompt=task_prompt,
    with_task_specify=False,
    output_language="中文"
)

print(
    Fore.GREEN
    + f"AI Assistant sys message:\n{role_play_session.assistant_sys_msg}\n"
)
print(Fore.BLUE + f"AI User sys message:\n{role_play_session.user_sys_msg}\n")

print(Fore.YELLOW + f"Original task prompt:\n{task_prompt}\n")
print(
    Fore.CYAN
    + "Specified task prompt:"
    + f"\n{role_play_session.specified_task_prompt}\n"
)
print(Fore.RED + f"Final task prompt:\n{role_play_session.task_prompt}\n")

# %% [markdown]
# 开始我们的Agent交互。
#
#  **注意** ：此会话大约需要 8 分钟。

# %%
n = 0
input_msg = role_play_session.init_chat()
while n < 20: # Limit the chat to 20 turns
    n += 1
    assistant_response, user_response = role_play_session.step(input_msg)

    if assistant_response.terminated:
        print(
            Fore.GREEN
            + (
                "AI Assistant terminated. Reason: "
                f"{assistant_response.info['termination_reasons']}."
            )
        )
        break
    if user_response.terminated:
        print(
            Fore.GREEN
            + (
                "AI User terminated. "
                f"Reason: {user_response.info['termination_reasons']}."
            )
        )
        break
    # Print output from the user
    print_text_animated(
        Fore.BLUE + f"AI User:\n\n{user_response.msg.content}\n",
        0.01
    )

    if "CAMEL_TASK_DONE" in user_response.msg.content:
        break

    # Print output from the assistant, including any function
    # execution information
    print_text_animated(Fore.GREEN + "AI Assistant:", 0.01)
    tool_calls: List[FunctionCallingRecord] = [
        FunctionCallingRecord(**call.as_dict())
        for call in assistant_response.info['tool_calls']
    ]
    for func_record in tool_calls:
        print_text_animated(f"{func_record}", 0.01)
    print_text_animated(f"{assistant_response.msg.content}\n", 0.01)

    input_msg = assistant_response.msg
