# %%
from camel.agents import TaskSpecifyAgent
from camel.models import ModelFactory
from camel.prompts import TextPrompt
from camel.types import ModelPlatformType
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv('ModelFactory_Key')

model = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI_COMPATIBLE_MODEL,
    model_type="Qwen/Qwen2.5-72B-Instruct",
    url='https://api-inference.modelscope.cn/v1/',
    api_key=api_key
)

my_prompt_template = TextPrompt(
    'Here is a task: I\'m a {occupation} and I want to {task}. Help me to make this task more specific.'
)  # 你可以根据需求自定义任何模板
task_specify_agent = TaskSpecifyAgent(
    model=model, task_specify_prompt=my_prompt_template
)
response = task_specify_agent.run(
    task_prompt="get promotion",
    meta_dict=dict(occupation="Software Engineer"),
)
print(response)
# Out:
# Certainly! To make your goal of getting a promotion as a Software Engineer more specific, you can break it down into clear, actionable steps. Here’s a more detailed plan:
#
# ### Specific Goal:
# **Achieve a promotion to Senior Software Engineer within the next 12 months.**
#
# ### Key Areas to Focus On:
# 1. **Skill Development**
#    - **Technical Skills**: Identify and master advanced programming languages, frameworks, and tools relevant to your role.
#      - Example: Learn and become proficient in Kubernetes, Docker, and cloud platforms like AWS or Azure.
#    - **Soft Skills**: Improve communication, leadership, and problem-solving skills.
#      - Example: Take a course on effective communication and leadership.
#
# 2. **Project Leadership**
#    - **Lead Projects**: Take on leadership roles in current projects to demonstrate your ability to manage and deliver.
#      - Example: Volunteer to lead a small team for an upcoming project.
#    - **Mentorship**: Mentor junior developers to show your commitment to team growth.
#      - Example: Offer to mentor one or two junior engineers.
#
# 3. **Performance Metrics**
#    - **Set Clear Goals**: Work with your manager to set specific, measurable goals that align with the company’s objectives.
#      - Example: Increase the efficiency of a critical system by 20%.
#    - **Track Progress**: Regularly update your manager on your progress and seek feedback.
#      - Example: Schedule monthly check-ins with your manager.
#
# 4. **Networking and Visibility**
#    - **Internal Networking**: Build relationships with key stakeholders and leaders in your organization.
#      - Example: Attend internal meetings and events to network with other teams.
#    - **External Networking**: Participate in industry conferences, webinars, and workshops.
#      - Example: Speak at a local tech meet-up or contribute to open-source projects.
#
# 5. **Documentation and Communication**
#    - **Document Achievements**: Keep a record of your accomplishments, including projects led, skills learned, and positive feedback received.
#      - Example: Maintain a professional portfolio or a personal log of achievements.
#    - **Regular Updates**: Provide regular updates to your manager and team on your progress and contributions.
#      - Example: Send a monthly email summarizing your recent achievements and ongoing projects.
#
# 6. **Feedback and Improvement**
#    - **Seek Feedback**: Regularly ask for feedback from your manager and peers to identify areas for improvement.
#      - Example: Request a mid-year review to discuss your performance and areas for growth.
#    - **Continuous Learning**: Stay updated with the latest industry trends and best practices.
#      - Example: Subscribe to tech newsletters and follow leading tech blogs.
#
# ### Action Plan:
# 1. **Month 1-2**:
#    - Meet with your manager to set clear, measurable goals.
#    - Identify and enroll in relevant courses or training programs.
# 2. **Month 3-4**:
#    - Start leading a small project or task.
#    - Begin mentoring a junior developer.
# 3. **Month 5-6**:
#    - Attend an industry conference or webinar.
#    - Schedule a mid-year review with your manager.
# 4. **Month 7-8**:
#    - Continue documenting your achievements and progress.
#    - Seek additional leadership opportunities within your team.
# 5. **Month 9-10**:
#    - Network with key stakeholders and leaders.
#    - Contribute to open-source projects or speak at a tech event.
# 6. **Month 11-12**:
#    - Prepare a comprehensive portfolio of your achievements.
#    - Schedule a performance review and discuss your readiness for a promotion.
#
# By breaking down your goal into these specific steps, you can create a clear path to achieving your promotion. Good luck!
